# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcinMarud/flyrank_internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MarcinMarud/flyrank_internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# Lane 1 - Ranking Signal Analysis. The core taks is classification.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# !git clone https://github.com/MarcinMarud/flyrank_internship.git
# %cd flyrank_internship

import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df["is_declining_label"] = (df["trend_direction"] == "down").astype(int)
print(df["is_declining_label"].value_counts(normalize=True))
# Out:
# Cloning into 'flyrank_internship'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 122 (delta 35), reused 93 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (122/122), 1.84 MiB | 13.21 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# /content/flyrank_internship
# is_declining_label
# 1    0.542067
# 0    0.457933
# Name: proportion, dtype: float64

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# Whether my model separates decliners from non-decliners better than chance. SO my main success metric is AUC-ROC

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df = df[(df["impressions_90d"] > 0) & (df["content_age_days"] >= 90)]
df = df.drop_duplicates(subset="content_id")

print("Shape:", df.shape)
df[["content_id", "client_id", "impressions_90d", "content_age_days", "trend_direction"]].head(10)
# Out:
# Shape: (30000, 44)
#              content_id          client_id  impressions_90d  content_age_days  \
# 0  content_304f48230142  client_f369cb89fc             3803               187
# 1  content_a1fb4e703a9e  client_4e07408562            15320               445
# 2  content_9aa793d4d895  client_7f2253d7e2            12581               141
# 3  content_331d6c4de07b  client_19581e27de            11751               463
# 4  content_d99b7a2d90ca  client_3fdba35f04            19140               263
# 5  content_d4084a4bc775  client_f369cb89fc             3970               147
# 6  content_9a34b442b552  client_8722616204               20                90
# 7  content_a63219c6e95a  client_19581e27de             1724               445
# 8  content_5e6c160719bc  client_6208ef0f77            32574                90
# 9  content_c27558df2b0c  client_19581e27de             1240               257
#
#   trend_direction
# 0            down
# 1            down
# 2            down
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
# Because fixed rule test only one signal at a time, chosen by a human guesswork, it can not detect combinations. Simple classifaier can detect and make use of many signal at the same time and rank them by importance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

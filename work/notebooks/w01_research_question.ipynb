# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcinMarud/flyrank_internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MarcinMarud/flyrank_internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# # I will choose lane 1, because i want to really understand what  drievs performance before ranking anything

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# # Decision - what content should be prioritized when wrtiting new pages, such as concise, verified information
# # False_postitive (cost of a wrong call): chase of a signal that is not real, which results in wasted efforts, such as information that was not verified

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The starter dataset has 30000 rows, and 44 columns. word_count shows a weak correlation 16,33% with impressions_90d. Which means that the depth / word_count is not tied to impressions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All

# !git clone https://github.com/MarcinMarud/flyrank_internship.git
# %cd flyrank_internship

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows, columns:", df.shape)

print(df[["word_count", "impressions_90d"]].corr())

print("Pages with impressions_90d >= 100:", (df["impressions_90d"] >= 100).sum())

print(df["position_tier"].value_counts())
# Out:
# fatal: destination path 'flyrank_internship' already exists and is not an empty directory.
# /content/flyrank_internship
# Rows, columns: (30000, 44)
#                  word_count  impressions_90d
# word_count         1.000000         0.163345
# impressions_90d    0.163345         1.000000
# Pages with impressions_90d >= 100: 22006
# position_tier
# page_1      11814
# striking     7304
# page_3_5     7242
# top_3        2321
# deep         1319
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# My work will be able to show what is really observed. Measurable content, search signals are associated with higher visibility or engaggement, based on historical data. Show how strong those assosciations are. It can inform directional and decision-support guidance for what to priotitize while writing new pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
